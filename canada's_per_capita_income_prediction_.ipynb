# %% [markdown]
# <a href="https://colab.research.google.com/github/imshibl/canada_per_capita_income_predictor/blob/main/canada's_per_capita_income_prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("canada_per_capita_income_data.csv")
new_df = df.rename(columns={"per capita income (US$)": "PCI"})

# %%
plt.ylabel("per capita income (US$) ")
plt.xlabel("year")
plt.scatter(new_df.year, new_df.PCI, color="red", marker="+")

# %%
lreg = linear_model.LinearRegression()
lreg.fit(new_df[["year"]], new_df.PCI)
# Out:
# LinearRegression()

# %%
lreg.predict([[2050]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([66142.6463511])

# %%
plt.ylabel("per capita income (US$) ")
plt.xlabel("year")
plt.scatter(new_df.year, new_df.PCI, color="red", marker="+")
plt.plot(new_df.year, lreg.predict(new_df[["year"]]), color="blue")

# %%
predictions = lreg.predict(new_df[["year"]])
r2 = r2_score(new_df.PCI, predictions)
print("R² Score:", r2)
# Out:
# R² Score: 0.890916917957032
